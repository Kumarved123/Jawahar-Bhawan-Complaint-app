# %%
import tkinter as tk
import os     
from tkinter import *
from tkinter.messagebox import *
from tkinter.filedialog import *
import webbrowser

root = tk.Tk()
root.title("JAWAHAR BHAWAN")
root.geometry("900x600")
Compliant_Type = Menubutton(root,text= 'Compliant Type',font = ('Helvetica', 12))
Compliant_Type.grid() 
Compliant_Type.menu  =  Menu ( Compliant_Type, tearoff = 0 ) 
Compliant_Type['menu']  =  Compliant_Type.menu 
Compliant_Type.menu.add_checkbutton ( label ='Fan',font = ('Helvetica', 12) ) 
Compliant_Type.menu.add_checkbutton ( label = 'Tube Light', font = ('Helvetica', 12))
Compliant_Type.menu.add_checkbutton ( label ='Furniture',font = ('Helvetica', 12) ) 
Compliant_Type.menu.add_checkbutton ( label = 'LAN', font = ('Helvetica', 12))
Compliant_Type.menu.add_checkbutton ( label = 'Other', font = ('Helvetica', 12))
Compliant_Type.pack()
Compliant_Type.place(height= 30, width = 250, x= 300,y=350)

heading = tk.Label(root, text = 'Jawahar Bhawan Complaint Portal', font = ('Helvetica', 25)) 
heading.pack()
heading.place(height= 40, width = 500, x= 300,y=20)




menu = Menu(root) 
root.config(menu=menu) 
filemenu = Menu(menu) 
menu.add_cascade(label='HOME', menu=filemenu) 
filemenu.add_command(label='New Complaint') 
filemenu.add_command(label='Old Compliant Status' ) 
filemenu.add_separator() 
filemenu.add_command(label='Exit', command=root.quit)
Coucilmenu = Menu(menu) 
menu.add_cascade(label='Council', menu=Coucilmenu)
Coucilmenu.add_command(label='Bhawan')
Coucilmenu.add_command(label='Mess')
Coucilmenu.add_command(label='Maintenance')
helpmenu = Menu(menu) 
menu.add_cascade(label='Help', menu=helpmenu) 
helpmenu.add_command(label='About')




l1 = tk.Label(root, text = 'Enter Your Name', font = ('Helvetica', 12))
l1.pack()
l1.place(height= 30, width = 250, x= 100,y=200)
l2 = tk.Label(root, text = 'Enter Your Room No.', font = ('Helvetica', 12))
l2.pack()
l2.place(height= 30, width = 250, x= 100,y=250)
l3 = tk.Label(root, text = 'Enter Your Mobile No.', font = ('Helvetica', 12))
l3.pack()
l3.place(height= 30, width = 250, x= 100,y=300)
l4 = tk.Label(root, text = 'Complain Type', font = ('Helvetica', 12))
l4.pack()
l4.place(height= 30, width = 250, x= 100,y=350)

e1 = Entry(root,font = ('Helvetica', 12))
e1.pack()
e1.place(height= 30, width = 250, x= 300,y=200)
e2 = Entry(root,font = ('Helvetica', 12))
e2.pack()
e2.place(height= 30, width = 250, x= 300,y=250)
e3 = Entry(root,font = ('Helvetica', 12))
e3.pack()
e3.place(height= 30, width = 250, x= 300,y=300)

button = tk.Button(root, text='Enter your Complant', width=25,font = ('Helvetica', 12) ) 
button.pack()
button.place(height= 30, width = 250, x= 300,y=400)









root.mainloop()
